# %% [markdown]
# Calculadora Simples

# %%
# Out:
#   File "<ipython-input-29-b0f5f20afe27>", line 15
#     print((str(numero1)+''+str(operacao)+''+ str(numero2)+'='+str(resultado))
#                                                                              ^
# SyntaxError: incomplete input
